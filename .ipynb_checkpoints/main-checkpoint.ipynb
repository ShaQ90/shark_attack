# %%
import pandas as pd
import numpy as np
import re
import my_functions as mf
from datetime import datetime

#define were the data comes from
df = pd.read_excel("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
#cleaning the data as we see fit

df = mf.cleaning_tool(df)
#reseting the index
df.reset_index()

# %%
#adding new column for time classification

df["Time_Calssification"] = df["Time"].apply(mf.classify_time)

# %%
#Convert date as date type

df["Date"] = df["Date"].apply(mf.convert_to_dates)

# %%
df
# Out:
#              Date    Year        Type    Country             State  \
# 0      2024-03-15  2024.0  Unprovoked  AUSTRALIA        Queensland
# 2     02 Mar-2024  2024.0  Unprovoked        USA            Hawaii
# 6     29 Jan-2024  2024.0  Unprovoked  AUSTRALIA  New  South Wales
# 8     09-Jan-2024  2024.0  Unprovoked  AUSTRALIA   South Australia
# 11    29 Dec-2023  2023.0  Unprovoked     MEXICO            Sonora
# ...           ...     ...         ...        ...               ...
# 6448  25-Nov-1880  1880.0  Unprovoked  AUSTRALIA        Queensland
# 6556  13-May-1868  1868.0  Unprovoked      INDIA      Hoogly River
# 6884        1960s     0.0  Unprovoked       IRAQ            Basrah
# 6885        1960s     0.0  Unprovoked       IRAQ            Basrah
# 6907    1941-1942     0.0  Unprovoked       IRAQ            Basrah
#
#                                          Location  Activity Sex   Age  \
# 0                                   Bargara Beach      swim   F   NaN
# 2                                  Rainbows, Oahu      swim   F   NaN
# 6                    Elizabeth Bay, Sydney Harbor      swim   F   NaN
# 8                         Walkers Beach, Elliston      surf   M   NaN
# 11             Tojahui Beach, Yavaros, Huatabampo    diving   M   NaN
# ...                                           ...       ...  ..   ...
# 6448                 Petrie Bight, Brisbane River      swim   M   NaN
# 6556                                         Ghat  Standing   M  35.0
# 6884                         Shatt-al-Arab River       swim   M   6.0
# 6885       Shatt-al-Arab River near Abu al Khasib      swim   M  16.0
# 6907  Shatt-el Arab River near a small boat stand      swim   M   NaN
#
#                                                  Injury          Time  \
# 0              Minor injuries to back, abdomen and legs         16h00
# 2                              Lacerations to left foot         13h30
# 6                                      Right leg bitten         20h00
# 8                                            Leg bitten         13h00
# 11                                                FATAL         13h00
# ...                                                 ...           ...
# 6448            Feet bitten, surgically amputated FATAL     Afternoon
# 6556  FATAL, upper left thigh, groin & buttocks seve...  Before 10h30
# 6884                                        Arm severed     Afternoon
# 6885         Right leg lacerated & surgically amputated     Afternoon
# 6907      FATAL, left leg bitten with severe blood loss     Afternoon
#
#                                            Species Time_Calssification
# 0                                      Tiger shark           Afternoon
# 2                                   3' to 4' shark           Afternoon
# 6                                       Bull shark             Evening
# 8                                      White shark           Afternoon
# 11                                     White shark           Afternoon
# ...                                            ...                 ...
# 6448                                    Bull shark           Afternoon
# 6556  Identified as C. gangeticus by Dr. J. Fayrer                 NaN
# 6884                                    Bull shark           Afternoon
# 6885                                    Bull shark           Afternoon
# 6907                                    Bull shark           Afternoon
#
# [1694 rows x 13 columns]
